# %%
from  gensim.models.doc2vec import Doc2Vec

# %%
ert = Doc2Vec.load('data/paragraphs.data')

# %%
ert['307']
# Out:
# array([-0.06265774, -0.44324604, -0.247953  ,  0.01086502, -0.15267596,
#         0.12370448, -0.17588046, -0.33453506,  0.18281111, -0.03947638,
#        -0.1404805 , -0.11728261,  0.01267381,  0.24348599,  0.05857065,
#        -0.14131562,  0.08962329,  0.00524235,  0.09904984, -0.1622575 ,
#        -0.19345789,  0.1696969 , -0.17106159, -0.11381514,  0.16147777,
#        -0.04324151, -0.23155822, -0.38623312,  0.1538909 ,  0.01087075,
#        -0.00766274,  0.09704868, -0.16250725, -0.07645961, -0.02908072,
#         0.14894514,  0.25550663,  0.22830059,  0.01120838,  0.04364509,
#        -0.00167299, -0.3746409 , -0.07756142,  0.10325357, -0.15161552,
#         0.11009097, -0.02259955, -0.04433371, -0.05039151,  0.00398409,
#         0.04260662,  0.13393418,  0.0943631 ,  0.0742981 , -0.02026398,
#        -0.24170955, -0.07327209, -0.00948344,  0.10340862, -0.04394058,
#         0.06403188, -0.09850343, -0.32372552,  0.24807452,  0.09477773,
# ...

# %%
ert.docvecs.doctags
# Out:
# {'307': Doctag(offset=0, word_count=9935, doc_count=1),
#  '627': Doctag(offset=1, word_count=4560, doc_count=1),
#  '642': Doctag(offset=2, word_count=147, doc_count=1),
#  '691': Doctag(offset=3, word_count=4100, doc_count=1),
#  '698': Doctag(offset=4, word_count=4540, doc_count=1),
#  '713': Doctag(offset=5, word_count=1562, doc_count=1),
#  '736': Doctag(offset=6, word_count=6149, doc_count=1),
#  '771': Doctag(offset=7, word_count=9590, doc_count=1),
#  '800': Doctag(offset=8, word_count=2945, doc_count=1),
#  '854': Doctag(offset=9, word_count=2484, doc_count=1),
#  '863': Doctag(offset=10, word_count=8757, doc_count=1),
#  '910': Doctag(offset=11, word_count=77, doc_count=1),
#  '928': Doctag(offset=12, word_count=2298, doc_count=1),
#  '954': Doctag(offset=13, word_count=5354, doc_count=1),
#  '984': Doctag(offset=14, word_count=5154, doc_count=1),
#  '1004': Doctag(offset=15, word_count=2436, doc_count=1),
#  '1005': Doctag(offset=16, word_count=1846, doc_count=1),
# ...
